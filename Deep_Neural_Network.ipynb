# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow.keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from sklearn import datasets

# %%
np.random.seed(0)

# %%
n_pts = 500
X,y = datasets.make_circles(n_samples = n_pts, random_state = 123, noise = 0.1, factor = 0.2)

# %%
plt.scatter(X[y==0,0], X[y==0,1])
plt.scatter(X[y==1,0], X[y==1,1])

# %%
model = Sequential()
model.add(Dense(4, input_shape = (2,), activation = 'sigmoid'))
model.add(Dense(1, activation = 'sigmoid'))
adam = Adam(lr = 0.1)
model.compile(adam, loss = 'binary_crossentropy', metrics = ['accuracy'])
h = model.fit(x=X, y=y, verbose = 1, batch_size = 20, epochs = 100, shuffle = 'true')
# Out:
# Epoch 1/100
# 25/25 [==============================] - 1s 2ms/step - loss: 0.7132 - accuracy: 0.5088
# Epoch 2/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.7096 - accuracy: 0.5398
# Epoch 3/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6724 - accuracy: 0.5269
# Epoch 4/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5572 - accuracy: 0.7842
# Epoch 5/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3489 - accuracy: 0.9268
# Epoch 6/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1859 - accuracy: 0.9942
# Epoch 7/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0908 - accuracy: 0.9998
# Epoch 8/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0599 - accuracy: 0.9986
# Epoch 9/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0439 - accuracy: 0.9998
# Epoch 10/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0357 - accuracy: 0.9992
# Epoch 11/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0280 - accuracy: 1.0000
# Epoch 12/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0255 - accuracy: 1.0000
# Epoch 13/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0193 - accuracy: 0.9984
# Epoch 14/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0185 - accuracy: 1.0000
# Epoch 15/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0172 - accuracy: 0.9993
# Epoch 16/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0149 - accuracy: 1.0000
# Epoch 17/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0140 - accuracy: 1.0000
# Epoch 18/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0117 - accuracy: 0.9998
# Epoch 19/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0097 - accuracy: 1.0000
# Epoch 20/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0117 - accuracy: 1.0000
# Epoch 21/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0091 - accuracy: 1.0000
# Epoch 22/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0124 - accuracy: 1.0000
# Epoch 23/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0102 - accuracy: 1.0000
# Epoch 24/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.9996
# Epoch 25/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0065 - accuracy: 1.0000
# Epoch 26/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0064 - accuracy: 1.0000
# Epoch 27/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0084 - accuracy: 1.0000
# Epoch 28/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0070 - accuracy: 1.0000
# Epoch 29/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0072 - accuracy: 1.0000
# Epoch 30/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0057 - accuracy: 0.9990
# Epoch 31/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0054 - accuracy: 1.0000
# Epoch 32/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0062 - accuracy: 0.9993
# Epoch 33/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0049 - accuracy: 1.0000
# Epoch 34/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0049 - accuracy: 0.9994
# Epoch 35/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0051 - accuracy: 1.0000
# Epoch 36/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0055 - accuracy: 1.0000
# Epoch 37/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0049 - accuracy: 0.9990
# Epoch 38/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0055 - accuracy: 1.0000
# Epoch 39/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0057 - accuracy: 1.0000
# Epoch 40/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0036 - accuracy: 1.0000
# Epoch 41/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 42/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 43/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 44/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0044 - accuracy: 1.00 - 0s 2ms/step - loss: 0.0043 - accuracy: 1.0000
# Epoch 45/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0043 - accuracy: 1.0000
# Epoch 46/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0037 - accuracy: 1.0000
# Epoch 47/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 48/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0042 - accuracy: 1.0000
# Epoch 49/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 50/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 51/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 52/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0036 - accuracy: 1.0000
# Epoch 53/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 54/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 55/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 56/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 57/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 58/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 59/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 60/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 61/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0037 - accuracy: 1.0000
# Epoch 62/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0049 - accuracy: 0.9973
# Epoch 63/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 64/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 65/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 66/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 67/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 68/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 69/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 70/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 71/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 72/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 73/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 74/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 75/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 76/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 77/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 78/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 79/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0041 - accuracy: 1.00 - 0s 2ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 80/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 81/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 82/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 83/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 84/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 85/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 86/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 87/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 88/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0025 - accuracy: 0.9995
# Epoch 89/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0028 - accuracy: 0.9993
# Epoch 90/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 91/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 92/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 1.0000   - 0s 2ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 93/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 94/100
# 25/25 [==============================] - 0s 1ms/step - loss: 8.3291e-04 - accuracy: 1.0000
# Epoch 95/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 96/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 97/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 98/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 99/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 100/100
# 25/25 [==============================] - 0s 2ms/step - loss: 8.8881e-04 - accuracy: 1.0000

# %%
plt.plot(h.history['accuracy'])
plt.legend(['accuracy'])
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.title('accuracy')
# Out:
# Text(0.5, 1.0, 'accuracy')

# %%
plt.plot(h.history['loss'])
plt.legend(['loss'])
plt.xlabel('epoch')
plt.ylabel('loss')
plt.title('loss')
# Out:
# Text(0.5, 1.0, 'loss')

# %%
def plot_decision_boundary(X,y,model):
    x_span = np.linspace(min(X[:,0])-0.25, max(X[:,0])+0.25)
    y_span = np.linspace(min(X[:,1])-0.25, max(X[:,1])+0.25)
    xx,yy = np.meshgrid(x_span,y_span)
    xx_,yy_ = xx.ravel(),yy.ravel()
    grid = np.c_[xx_,yy_]
    predic_func = model.predict(grid)
    z = predictf = predic_func.reshape(xx.shape)
    plt.contourf(xx,yy,z)

# %%
plot_decision_boundary(X,y,model)

# %%
plot_decision_boundary(X,y,model)
plt.scatter(X[y==0,0], X[y==0,1])
plt.scatter(X[y==1,0], X[y==1,1])

# %%
plot_decision_boundary(X,y,model)
plt.scatter(X[y==0,0], X[y==0,1])
plt.scatter(X[y==1,0], X[y==1,1])
x = 0.3
y = 0.4

point = np.array([[x,y]])
prediction = model.predict(point)
print("prediction is :", prediction)
plt.plot([x], [y], marker = 'o', markersize = 10, color = 'r')
# Out:
# prediction is : [[0.96807396]]
